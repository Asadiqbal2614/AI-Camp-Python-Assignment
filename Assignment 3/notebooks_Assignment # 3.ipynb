# %%
print("Task 1")

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("1.Add 2.Subtract 3.Multiply 4.Divide 5.Power")
choice = int(input("Choose (1-5): "))

if choice == 1:
    print(num1 + num2)
elif choice == 2:
    print(num1 - num2)
elif choice == 3:
    print(num1 * num2)
elif choice == 4:
    print(num1 / num2)
elif choice == 5:
    print(num1 ** num2)
else:
    print("Invalid")
# Out:
# Task 1
# Enter first number:  5
# Enter second number:  7
# 1.Add 2.Subtract 3.Multiply 4.Divide 5.Power
# Choose (1-5):  3
# 35.0

# %%
print("Task 2")

my_list = ["Ali", 10, "Asad", 3.5]

for item in my_list:
    if type(item) == int or type(item) == float:
        print("Numeric value exists")
        break
# Out:
# Task 2
# Numeric value exists

# %%
print("Task 3")

student = {"name": "Asad", "age": 22}
student["city"] = "Hyderabad"
print(student)
# Out:
# Task 3
# {'name': 'Asad', 'age': 22, 'city': 'Hyderabad'}

# %%
print("Task 4")

data = {"a": 10, "b": 20, "c": 30}

total = 0

for value in data.values():
    total = total + value

print(total)
# Out:
# Task 4
# 60

# %%
print("Task 5")

numbers = [1, 2, 3, 2, 4, 5, 1]

duplicates = []

for num in numbers:
    if numbers.count(num) > 1 and num not in duplicates:
        duplicates.append(num)

print(duplicates)
# Out:
# Task 5
# [1, 2]

# %%
print("Task 6")

person = {"name": "Asad", "age": 22}

key = input("Enter key: ")

if key in person:
    print("Key exists")
else:
    print("Key not exists")
# Out:
# Task 6
# Enter key:  city
# Key not exists
