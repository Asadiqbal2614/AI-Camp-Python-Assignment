# %%
print("Task 1")
data = [10, "Asad", 5.5, True, "AI"]
print("Length of list is:", len(data))
# Out:
# Task 1
# Length of list is: 5

# %%
print("Task 2")
numbers = [12, 7.5, 3, 10]
print("Sum of numeric items is:", sum(numbers))
# Out:
# Task 2
# Sum of numeric items is: 32.5

# %%
print("Task 3")
values = [45, 12.5, 99, 23]
print("Largest number is:", max(values))
# Out:
# Task 3
# Largest number is: 99

# %%
print("Task 4")
my_list = [7, 2, 9, 1, 6, 3, 12]
if my_list[0] < 5:
    print(my_list[0])
if my_list[1] < 5:
    print(my_list[1])
if my_list[2] < 5:
    print(my_list[2])
if my_list[3] < 5:
    print(my_list[3])
if my_list[4] < 5:
    print(my_list[4])
if my_list[5] < 5:
    print(my_list[5])
if my_list[6] < 5:
    print(my_list[6])
# Out:
# Task 4
# 2
# 1
# 3
